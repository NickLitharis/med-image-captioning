# %%
import pandas as pd
import os
import shutil

# %%
# Path to the CSV file
csv_file_path='C:\\Users\\Νίκος Λιθαρής\\OneDrive - ionio.gr\\Desktop\\med-image-captioning\\data\\csv\\image_uri_and_captions_100.csv'

# load the file to df
df = pd.read_csv(csv_file_path)

# %%
# get the path to the images
for entry in range(len(df['image_uri'])):
    # print(entry)
    image_path = str(df['image_uri'][entry])
    print(image_path)
    source=os.path.join('D:\\thesis\\medicat_release\\release\\figures\\',image_path)
# print(source)
    destination=os.path.join('C:\\Users\\Νίκος Λιθαρής\\OneDrive - ionio.gr\\Desktop\\med-image-captioning\\images\\',image_path)
    shutil.copy(source, destination)
# Out:
# 780d51420ad492a61d00295adb6919bd492e6bd3_8-Figure3-1.png
# 4fd909ba5e5ee6d90fae6967acd2f54cc9f8b4bf_4-Figure7-1.png
# 2b67d96df5488d5c3320f1626ba098c1b10b5a17_1-Figure2-1.png
# 11357dcc40909413166afbddffe7b6b2f2e3309b_8-Figure2-1.png
# ba5b8e81fb34a0c30922cdcc04f7bef567330e39_2-Figure1-1.png
# ee752c4d1b580145280d26592dee4d591300fcf5_2-Figure1-1.png
# 24235a2e81fbb062b1ad2d169185d3858332faf9_5-Figure2-1.png
# dcbfd9fab8d4075e5b9db4871b8c4e7b09dc55f0_2-Figure2-1.png
# 372fb608834f67a7b516fa1841975ab638261171_2-Figure1-1.png
# 00bca1a68e08189c05cd2a1d0d6e23832303b475_2-Figure1-1.png
# 918a87db6d5a201d0c92797b3a2b228dd1a9c04d_2-Figure1-1.png
# 6339fcacfbee4d722bf5759ba27cabdaab9de652_1-Figure1-1.png
# c8eacf6f86b2c846f23cf8861ed2d07a820fc1ba_6-Figure11-1.png
# fe59a0fc82d6c6ae1f3b04bfb597ede6fc491c24_2-Figure2-1.png
# 8636be9301565311d21cf3cf35c512c105ac937a_2-Figure1-1.png
# 70c234dd96e29ca4e6aec0aaff51a8f88e612557_4-Figure4-1.png
# ...
